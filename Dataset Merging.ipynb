# %%
import pandas as pd

# %%
breweries = pd.read_csv("Resources/Clean/texas_breweries.csv")

# %%
beers = pd.read_csv("Resources/Clean/texas_beers.csv")

# %%
reviews = pd.read_csv("Resources/Clean/texas_reviews.csv")

# %%
breweries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323 entries, 0 to 322
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       323 non-null    int64
#  1   name     323 non-null    object
#  2   city     323 non-null    object
#  3   state    323 non-null    object
#  4   country  323 non-null    object
#  5   types    323 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 15.3+ KB

# %%
beers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4885 entries, 0 to 4884
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            4885 non-null   int64
#  1   name          4885 non-null   object
#  2   brewery_id    4885 non-null   int64
#  3   style         4885 non-null   object
#  4   availability  4885 non-null   object
#  5   abv           4885 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 229.1+ KB

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75417 entries, 0 to 75416
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   beer_id  75417 non-null  int64
#  1   look     75417 non-null  float64
#  2   smell    75417 non-null  float64
#  3   taste    75417 non-null  float64
#  4   feel     75417 non-null  float64
#  5   overall  75417 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 3.5 MB

# %%
merged1 = pd.merge(reviews, beers, left_on='beer_id', right_on='id')
merged1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75417 entries, 0 to 75416
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   beer_id       75417 non-null  int64
#  1   look          75417 non-null  float64
#  2   smell         75417 non-null  float64
#  3   taste         75417 non-null  float64
#  4   feel          75417 non-null  float64
#  5   overall       75417 non-null  float64
#  6   id            75417 non-null  int64
#  7   name          75417 non-null  object
#  8   brewery_id    75417 non-null  int64
#  9   style         75417 non-null  object
#  10  availability  75417 non-null  object
#  11  abv           75417 non-null  float64
# dtypes: float64(6), int64(3), object(3)
# memory usage: 7.5+ MB

# %%
merged1 = merged1.drop('id', axis=1)

# %%
merged1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75417 entries, 0 to 75416
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   beer_id       75417 non-null  int64
#  1   look          75417 non-null  float64
#  2   smell         75417 non-null  float64
#  3   taste         75417 non-null  float64
#  4   feel          75417 non-null  float64
#  5   overall       75417 non-null  float64
#  6   name          75417 non-null  object
#  7   brewery_id    75417 non-null  int64
#  8   style         75417 non-null  object
#  9   availability  75417 non-null  object
#  10  abv           75417 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 6.9+ MB

# %%
merged1.head()
# Out:
#    beer_id  look  smell  taste  feel  overall                     name  \
# 0   203086  3.50   3.50   3.00  3.50     3.25  Hopper House Double IPA
# 1   203086  2.75   2.75   2.75  2.75     2.75  Hopper House Double IPA
# 2   203086  3.00   3.00   3.00  3.00     3.00  Hopper House Double IPA
# 3   203086  3.00   3.00   2.75  2.75     2.75  Hopper House Double IPA
# 4   203086  4.00   3.50   3.75  3.75     3.75  Hopper House Double IPA
#
#    brewery_id                  style availability  abv
# 0       43368  American Imperial IPA   Year-round  8.0
# 1       43368  American Imperial IPA   Year-round  8.0
# 2       43368  American Imperial IPA   Year-round  8.0
# 3       43368  American Imperial IPA   Year-round  8.0
# 4       43368  American Imperial IPA   Year-round  8.0

# %%
merged1 = merged1.drop('beer_id', axis=1)

# %%
merged2 = pd.merge(merged1, breweries, left_on='brewery_id', right_on='id')
merged2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 75417 entries, 0 to 75416
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   look          75417 non-null  float64
#  1   smell         75417 non-null  float64
#  2   taste         75417 non-null  float64
#  3   feel          75417 non-null  float64
#  4   overall       75417 non-null  float64
#  5   name_x        75417 non-null  object
#  6   brewery_id    75417 non-null  int64
#  7   style         75417 non-null  object
#  8   availability  75417 non-null  object
#  9   abv           75417 non-null  float64
#  10  id            75417 non-null  int64
#  11  name_y        75417 non-null  object
#  12  city          75417 non-null  object
#  13  state         75417 non-null  object
#  14  country       75417 non-null  object
#  15  types         75417 non-null  object
# dtypes: float64(6), int64(2), object(8)
# memory usage: 9.8+ MB

# %%
merged2 = merged2.drop('brewery_id', axis=1)

# %%
merged2 = merged2.drop('id', axis=1)

# %%
merged2.head(20)
# Out:
#     look  smell  taste  feel  overall                   name_x  \
# 0   3.50   3.50   3.00  3.50     3.25  Hopper House Double IPA
# 1   2.75   2.75   2.75  2.75     2.75  Hopper House Double IPA
# 2   3.00   3.00   3.00  3.00     3.00  Hopper House Double IPA
# 3   3.00   3.00   2.75  2.75     2.75  Hopper House Double IPA
# 4   4.00   3.50   3.75  3.75     3.75  Hopper House Double IPA
# 5   3.25   3.25   3.25  3.25     3.25  Hopper House Double IPA
# 6   2.75   2.75   2.75  2.75     2.75  Hopper House Double IPA
# 7   4.00   3.75   3.50  3.50     3.50  Hopper House Double IPA
# 8   3.50   3.25   3.50  3.50     3.25  Hopper House Double IPA
# 9   3.75   4.25   4.00  3.75     4.00  Hopper House Double IPA
# 10  3.00   3.25   3.25  3.25     3.25  Hopper House Double IPA
# 11  3.75   3.75   4.00  4.00     4.00  Hopper House Double IPA
# 12  3.00   3.50   3.25  3.25     3.50  Hopper House Double IPA
# 13  4.25   4.75   4.50  4.25     4.50     Diamonds in my Mouth
# 14  4.25   4.25   4.25  4.25     4.25     Diamonds in my Mouth
# 15  4.25   4.25   4.50  4.25     4.25     Diamonds in my Mouth
# 16  4.50   4.25   4.50  4.25     4.25     Diamonds in my Mouth
# 17  4.00   4.50   4.25  4.25     4.25     Diamonds in my Mouth
# 18  4.25   4.25   4.50  4.50     4.25     Diamonds in my Mouth
# 19  4.00   4.00   3.75  3.75     3.75     Diamonds in my Mouth
#
#                     style           availability  abv              name_y  \
# 0   American Imperial IPA             Year-round  8.0  Spindletap Brewery
# 1   American Imperial IPA             Year-round  8.0  Spindletap Brewery
# 2   American Imperial IPA             Year-round  8.0  Spindletap Brewery
# 3   American Imperial IPA             Year-round  8.0  Spindletap Brewery
# 4   American Imperial IPA             Year-round  8.0  Spindletap Brewery
# 5   American Imperial IPA             Year-round  8.0  Spindletap Brewery
# 6   American Imperial IPA             Year-round  8.0  Spindletap Brewery
# 7   American Imperial IPA             Year-round  8.0  Spindletap Brewery
# 8   American Imperial IPA             Year-round  8.0  Spindletap Brewery
# 9   American Imperial IPA             Year-round  8.0  Spindletap Brewery
# 10  American Imperial IPA             Year-round  8.0  Spindletap Brewery
# 11  American Imperial IPA             Year-round  8.0  Spindletap Brewery
# 12  American Imperial IPA             Year-round  8.0  Spindletap Brewery
# 13        New England IPA  Limited (brewed once)  8.0  Spindletap Brewery
# 14        New England IPA  Limited (brewed once)  8.0  Spindletap Brewery
# 15        New England IPA  Limited (brewed once)  8.0  Spindletap Brewery
# 16        New England IPA  Limited (brewed once)  8.0  Spindletap Brewery
# 17        New England IPA  Limited (brewed once)  8.0  Spindletap Brewery
# 18        New England IPA  Limited (brewed once)  8.0  Spindletap Brewery
# 19        New England IPA  Limited (brewed once)  8.0  Spindletap Brewery
#
#        city state country         types
# 0   Houston    TX      US  Brewery, Bar
# 1   Houston    TX      US  Brewery, Bar
# 2   Houston    TX      US  Brewery, Bar
# 3   Houston    TX      US  Brewery, Bar
# 4   Houston    TX      US  Brewery, Bar
# 5   Houston    TX      US  Brewery, Bar
# 6   Houston    TX      US  Brewery, Bar
# 7   Houston    TX      US  Brewery, Bar
# 8   Houston    TX      US  Brewery, Bar
# 9   Houston    TX      US  Brewery, Bar
# 10  Houston    TX      US  Brewery, Bar
# 11  Houston    TX      US  Brewery, Bar
# 12  Houston    TX      US  Brewery, Bar
# 13  Houston    TX      US  Brewery, Bar
# 14  Houston    TX      US  Brewery, Bar
# 15  Houston    TX      US  Brewery, Bar
# 16  Houston    TX      US  Brewery, Bar
# 17  Houston    TX      US  Brewery, Bar
# 18  Houston    TX      US  Brewery, Bar
# 19  Houston    TX      US  Brewery, Bar

# %%
merged2 = merged2.rename(columns={'name_x': 'beer_name', 'name_y': 'brewery_name'})

# %%
reviews_merged = merged2.reindex(columns=["beer_name", "style", "look", "smell", "taste", "feel", "overall", "availability", "abv", "brewery_name", "city", "state", "country", "types"])
reviews_merged.head(20)
# Out:
#                   beer_name                  style  look  smell  taste  feel  \
# 0   Hopper House Double IPA  American Imperial IPA  3.50   3.50   3.00  3.50
# 1   Hopper House Double IPA  American Imperial IPA  2.75   2.75   2.75  2.75
# 2   Hopper House Double IPA  American Imperial IPA  3.00   3.00   3.00  3.00
# 3   Hopper House Double IPA  American Imperial IPA  3.00   3.00   2.75  2.75
# 4   Hopper House Double IPA  American Imperial IPA  4.00   3.50   3.75  3.75
# 5   Hopper House Double IPA  American Imperial IPA  3.25   3.25   3.25  3.25
# 6   Hopper House Double IPA  American Imperial IPA  2.75   2.75   2.75  2.75
# 7   Hopper House Double IPA  American Imperial IPA  4.00   3.75   3.50  3.50
# 8   Hopper House Double IPA  American Imperial IPA  3.50   3.25   3.50  3.50
# 9   Hopper House Double IPA  American Imperial IPA  3.75   4.25   4.00  3.75
# 10  Hopper House Double IPA  American Imperial IPA  3.00   3.25   3.25  3.25
# 11  Hopper House Double IPA  American Imperial IPA  3.75   3.75   4.00  4.00
# 12  Hopper House Double IPA  American Imperial IPA  3.00   3.50   3.25  3.25
# 13     Diamonds in my Mouth        New England IPA  4.25   4.75   4.50  4.25
# 14     Diamonds in my Mouth        New England IPA  4.25   4.25   4.25  4.25
# 15     Diamonds in my Mouth        New England IPA  4.25   4.25   4.50  4.25
# 16     Diamonds in my Mouth        New England IPA  4.50   4.25   4.50  4.25
# 17     Diamonds in my Mouth        New England IPA  4.00   4.50   4.25  4.25
# 18     Diamonds in my Mouth        New England IPA  4.25   4.25   4.50  4.50
# 19     Diamonds in my Mouth        New England IPA  4.00   4.00   3.75  3.75
#
#     overall           availability  abv        brewery_name     city state  \
# 0      3.25             Year-round  8.0  Spindletap Brewery  Houston    TX
# 1      2.75             Year-round  8.0  Spindletap Brewery  Houston    TX
# 2      3.00             Year-round  8.0  Spindletap Brewery  Houston    TX
# 3      2.75             Year-round  8.0  Spindletap Brewery  Houston    TX
# 4      3.75             Year-round  8.0  Spindletap Brewery  Houston    TX
# 5      3.25             Year-round  8.0  Spindletap Brewery  Houston    TX
# 6      2.75             Year-round  8.0  Spindletap Brewery  Houston    TX
# 7      3.50             Year-round  8.0  Spindletap Brewery  Houston    TX
# 8      3.25             Year-round  8.0  Spindletap Brewery  Houston    TX
# 9      4.00             Year-round  8.0  Spindletap Brewery  Houston    TX
# 10     3.25             Year-round  8.0  Spindletap Brewery  Houston    TX
# 11     4.00             Year-round  8.0  Spindletap Brewery  Houston    TX
# 12     3.50             Year-round  8.0  Spindletap Brewery  Houston    TX
# 13     4.50  Limited (brewed once)  8.0  Spindletap Brewery  Houston    TX
# 14     4.25  Limited (brewed once)  8.0  Spindletap Brewery  Houston    TX
# 15     4.25  Limited (brewed once)  8.0  Spindletap Brewery  Houston    TX
# 16     4.25  Limited (brewed once)  8.0  Spindletap Brewery  Houston    TX
# 17     4.25  Limited (brewed once)  8.0  Spindletap Brewery  Houston    TX
# 18     4.25  Limited (brewed once)  8.0  Spindletap Brewery  Houston    TX
# 19     3.75  Limited (brewed once)  8.0  Spindletap Brewery  Houston    TX
#
#    country         types
# 0       US  Brewery, Bar
# 1       US  Brewery, Bar
# 2       US  Brewery, Bar
# 3       US  Brewery, Bar
# 4       US  Brewery, Bar
# 5       US  Brewery, Bar
# 6       US  Brewery, Bar
# 7       US  Brewery, Bar
# 8       US  Brewery, Bar
# 9       US  Brewery, Bar
# 10      US  Brewery, Bar
# 11      US  Brewery, Bar
# 12      US  Brewery, Bar
# 13      US  Brewery, Bar
# 14      US  Brewery, Bar
# 15      US  Brewery, Bar
# 16      US  Brewery, Bar
# 17      US  Brewery, Bar
# 18      US  Brewery, Bar
# 19      US  Brewery, Bar

# %%
reviews_merged.to_csv('Resources/Clean/reviews_merged.csv', index=False)
